# %% [markdown]
# # Importing the library

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in e:\python\python\lib\site-packages (3.1.2)
# Requirement already satisfied: numpy in e:\python\python\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in e:\python\python\lib\site-packages (from xgboost) (1.16.3)

# %%
pip install scikit-learn imbalanced-learn --upgrade
# Out:
# Requirement already satisfied: scikit-learn in e:\python\python\lib\site-packages (1.8.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: imbalanced-learn in e:\python\python\lib\site-packages (0.14.1)
# Requirement already satisfied: numpy>=1.24.1 in e:\python\python\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in e:\python\python\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in e:\python\python\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in e:\python\python\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in e:\python\python\lib\site-packages (from imbalanced-learn) (0.1.5)

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, mean_squared_error
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
import joblib

# %% [markdown]
# # Pre required Steps

# %%
df = pd.read_csv("new_cleaned_cardio_data.csv")
target = "cardio"

# %%
X = df.drop(columns=['id', 'cardio', 'age', 'height'])
y = df['cardio']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42, stratify=y)

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

joblib.dump(scaler, "standard_scaler.joblib")
# Out:
# ['standard_scaler.joblib']

# %% [markdown]
# # Smote balance

# %%
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(x_train_scaled, y_train)
x_train_res,y_train_res = smote.fit_resample(x_train_scaled,y_train)
print(f"Original training shape: {x_train_scaled.shape}")
print(f"SMOTE training shape: {X_train_smote.shape}")
# Out:
# Original training shape: (56251, 14)
# SMOTE training shape: (56936, 14)

# %% [markdown]
# # MODELS

# %% [markdown]
# # -> Decision Tree

# %%
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train_smote, y_train_smote)

dt_pred = dt.predict(x_test_scaled)
mse = mean_squared_error(y_test, dt_pred)


print("Decision Tree Model Performance:")
print("Accuracy:", accuracy_score(y_test, dt_pred))
print("MSE:", mse)
# Out:
# Decision Tree Model Performance:
# Accuracy: 0.6168613021916494
# MSE: 0.38313869780835064

# %% [markdown]
# # -> Linear Regression

# %%
lr = LinearRegression()
lr.fit(X_train_smote, y_train_smote)
lr_pred_raw = lr.predict(x_test_scaled)
lr_pred = [1 if val >= 0.5 else 0 for val in lr_pred_raw]

mse = mean_squared_error(y_test, lr_pred)

print("Linear Regression Model Performance:")
print("Accuracy:", accuracy_score(y_test, lr_pred))
print("MSE:", mse)
# Out:
# Linear Regression Model Performance:
# Accuracy: 0.7198848184290514
# MSE: 0.28011518157094867

# %% [markdown]
# # -> Logistic Regression

# %%
logreg = LogisticRegression(max_iter=5000, random_state=42)
logreg.fit(x_train_res,y_train_res)

logref_pred = logreg.predict(x_test_scaled)

mse = mean_squared_error(y_test, logref_pred)

print("Logistic Regression Model Performance:")
print("Accuracy:", accuracy_score(y_test, logref_pred))
print("MSE:", mse)
# Out:
# Logistic Regression Model Performance:
# Accuracy: 0.7194048952167653
# MSE: 0.2805951047832347

# %% [markdown]
# # -> Random Forest

# %%
rf = RandomForestClassifier(n_estimators=300,max_depth=12,min_samples_split=4, random_state=42)
rf.fit(x_train_res, y_train_res)

rf_pred = rf.predict(x_test_scaled)

mse = mean_squared_error(y_test, rf_pred)

print("Random Forest Model Performance:")
print("Accuracy:", accuracy_score(y_test, rf_pred))
print("MSE:", mse)
# Out:
# Random Forest Model Performance:
# Accuracy: 0.7277235642297233
# MSE: 0.27227643577027677

# %% [markdown]
# # -> XGBoost

# %%
xgb = XGBClassifier(
    n_estimators=300,
    max_depth=8,
    learning_rate=0.05,
    subsample=0.9,
    colsample_bytree=0.9,
    objective="binary:logistic",
    eval_metric="logloss"
)

xgb.fit(x_train_res, y_train_res)

xgb_pred = xgb.predict(x_test_scaled)
acc_xgb = accuracy_score(y_test, xgb_pred)

mse = mean_squared_error(y_test, xgb_pred)


print("XGBoost Model Performance:")
print("Accuracy:", acc_xgb)
print("MSE:", mse)
# Out:
# XGBoost Model Performance:
# Accuracy: 0.725323948168293
# MSE: 0.2746760518317069

# %% [markdown]
# # -> KNN

# %%
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(x_train_res, y_train_res)

knn_pred = knn.predict(x_test_scaled)

mse = mean_squared_error(y_test, knn_pred)

print("KNN Model Performance:")
print("Accuracy:", accuracy_score(y_test, knn_pred))
print("MSE:", mse)
# Out:
# KNN Model Performance:
# Accuracy: 0.7120460726283795
# MSE: 0.28795392737162057

# %% [markdown]
# # -> SVM

# %%
svc = SVC(kernel='rbf', random_state=42)
svc.fit(x_train_res, y_train_res)

svc_pred = svc.predict(x_test_scaled)

mse = mean_squared_error(y_test, svc_pred)

print("SVM Model Performance:")
print("Accuracy:", accuracy_score(y_test, svc_pred))
print("MSE:", mse)

# %% [markdown]
# # -> CAT Boost

# %%
pip install catboost
# Out:
# Requirement already satisfied: catboost in e:\python\python\lib\site-packages (1.2.8)
# Requirement already satisfied: graphviz in e:\python\python\lib\site-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in e:\python\python\lib\site-packages (from catboost) (3.9.2)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in e:\python\python\lib\site-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in e:\python\python\lib\site-packages (from catboost) (2.3.3)
# Requirement already satisfied: scipy in e:\python\python\lib\site-packages (from catboost) (1.16.3)
# Requirement already satisfied: plotly in e:\python\python\lib\site-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in e:\python\python\lib\site-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\python\python\lib\site-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\python\python\lib\site-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\python\python\lib\site-packages (from pandas>=0.24->catboost) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in e:\python\python\lib\site-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in e:\python\python\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\python\python\lib\site-packages (from matplotlib->catboost) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\python\python\lib\site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in e:\python\python\lib\site-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=8 in e:\python\python\lib\site-packages (from matplotlib->catboost) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\python\python\lib\site-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in e:\python\python\lib\site-packages (from plotly->catboost) (8.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from catboost import CatBoostClassifier
from sklearn.model_selection import GridSearchCV

# %%
catboost = CatBoostClassifier(
    iterations=300,        
    depth=8,               
    learning_rate=0.05,
    loss_function="Logloss",
    eval_metric="Logloss",
    random_seed=42,
    verbose=0                
)


catboost.fit(
    x_train_res,
    y_train_res
)


catboost_pred = catboost.predict(x_test_scaled)

acc_catboost = accuracy_score(y_test, catboost_pred)
mse = mean_squared_error(y_test, catboost_pred)

print("CatBoost Model Performance:")
print("Accuracy:", acc_catboost)
print("MSE:", mse)
# Out:
# CatBoost Model Performance:
# Accuracy: 0.7283634618461047
# MSE: 0.2716365381538954

# %% [markdown]
# # -> Catboost hyperparameter tuning(GridSearchCV)

# %%
from sklearn.model_selection import GridSearchCV

# %%
from catboost import CatBoostClassifier

cat_model = CatBoostClassifier(
    loss_function='Logloss',
    eval_metric='Accuracy',
    random_state=42,
    verbose=0,
)

param_grid = {
    'iterations': [200, 300],
    'learning_rate': [0.05, 0.1],
    'depth': [4, 6]
}

grid_result = cat_model.grid_search(
    param_grid,
    X=X_train_smote,
    y=y_train_smote,
    cv=3,
    plot=False
)
# Out:
# bestTest = 0.7316473481
# bestIteration = 120
#
# 0:	loss: 0.7316473	best: 0.7316473 (0)	total: 4.07s	remaining: 28.5s
#
# bestTest = 0.7327010889
# bestIteration = 197
#
# 1:	loss: 0.7327011	best: 0.7327011 (1)	total: 13.2s	remaining: 39.5s
#
# bestTest = 0.7320864067
# bestIteration = 298
#
# 2:	loss: 0.7320864	best: 0.7327011 (1)	total: 19.2s	remaining: 32s
#
# bestTest = 0.733315771
# bestIteration = 215
#
# 3:	loss: 0.7333158	best: 0.7333158 (3)	total: 27.6s	remaining: 27.6s
#
# bestTest = 0.7313839129
# bestIteration = 172
#
# 4:	loss: 0.7313839	best: 0.7333158 (3)	total: 34.1s	remaining: 20.5s
#
# bestTest = 0.7326132771
# bestIteration = 153
#
# 5:	loss: 0.7326133	best: 0.7333158 (3)	total: 38.2s	remaining: 12.7s
#
# bestTest = 0.731998595
# bestIteration = 278
#
# 6:	loss: 0.7319986	best: 0.7333158 (3)	total: 44.1s	remaining: 6.3s
#
# bestTest = 0.7326132771
# bestIteration = 153
#
# 7:	loss: 0.7326133	best: 0.7333158 (3)	total: 50.3s	remaining: 0us
# Estimating final quality...
# Training on fold [0/3]
#
# bestTest = 0.7294520548
# bestIteration = 132
#
# Training on fold [1/3]
#
# bestTest = 0.73200548
# bestIteration = 296
#
# Training on fold [2/3]
#
# bestTest = 0.7312677837
# bestIteration = 296

# %%
cat_model.fit(X_train_smote, y_train_smote)

# %%
best_catboost = cat_model

# %%
y_pred = best_catboost.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print("Tuned CatBoost Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Tuned CatBoost Accuracy: 0.48664213725803873

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("CatBoost Confusion Matrix")
plt.show()

# %%
print("Best Parameters:")
print(grid_result['params'])
# Out:
# Best Parameters:
# {'depth': 4, 'learning_rate': 0.1, 'iterations': 300}

# %%
best_accuracy = max(grid_result['cv_results']['test-Accuracy-mean'])
print("Best CV Accuracy:", best_accuracy)
# Out:
# Best CV Accuracy: 0.7307328160612497

# %%
grid_search.fit(X_train_smote, y_train_smote)

best_catboost = grid_search.best_estimator_

print("Best Parameters:", grid_search.best_params_)
print("Best CV Accuracy:", grid_search.best_score_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File E:\Python\python\Lib\site-packages\sklearn\utils\_tags.py:275, in get_tags(estimator)
#     274 try:
# --> 275     tags = estimator.__sklearn_tags__()
#     276 except AttributeError as exc:
#
# AttributeError: 'CatBoostClassifier' object has no attribute '__sklearn_tags__'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 grid_search.fit(X_train_smote, y_train_smote)
#       3 best_catboost = grid_search.best_estimator_
#       5 print("Best Parameters:", grid_search.best_params_)
#
# File E:\Python\python\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File E:\Python\python\Lib\site-packages\sklearn\model_selection\_search.py:962, in BaseSearchCV.fit(self, X, y, **params)
#     958 params = _check_method_params(X, params=params)
#     960 routed_params = self._get_routed_params_for_fit(params)
# --> 962 cv_orig = check_cv(self.cv, y, classifier=is_classifier(estimator))
#     963 n_splits = cv_orig.get_n_splits(X, y, **routed_params.splitter.split)
#     965 base_estimator = clone(self.estimator)
#
# File E:\Python\python\Lib\site-packages\sklearn\base.py:1211, in is_classifier(estimator)
#    1183 def is_classifier(estimator):
#    1184     """Return True if the given estimator is (probably) a classifier.
#    1185
#    1186     Parameters
#    (...)
#    1209     False
#    1210     """
# -> 1211     return get_tags(estimator).estimator_type == "classifier"
#
# File E:\Python\python\Lib\site-packages\sklearn\utils\_tags.py:283, in get_tags(estimator)
#     276 except AttributeError as exc:
#     277     if "object has no attribute '__sklearn_tags__'" in str(exc):
#     278         # Happens when `__sklearn_tags__` is implemented by calling
#     279         # `super().__sklearn_tags__()` but there is no `__sklearn_tags__`
#     280         # method in the base class. Typically happens when only inheriting
#     281         # from Mixins.
# --> 283         raise AttributeError(
#     284             f"The following error was raised: {exc}. It seems that "
#     285             "there are no classes that implement `__sklearn_tags__` "
#     286             "in the MRO and/or all classes in the MRO call "
#     287             "`super().__sklearn_tags__()`. Make sure to inherit from "
#     288             "`BaseEstimator` which implements `__sklearn_tags__` (or "
#     289             "alternatively define `__sklearn_tags__` but we don't recommend "
#     290             "this approach). Note that `BaseEstimator` needs to be on the "
#     291             "right side of other Mixins in the inheritance order."
#     292         )
#     293     else:
#     294         raise
#
# AttributeError: The following error was raised: 'CatBoostClassifier' object has no attribute '__sklearn_tags__'. It seems that there are no classes that implement `__sklearn_tags__` in the MRO and/or all classes in the MRO call `super().__sklearn_tags__()`. Make sure to inherit from `BaseEstimator` which implements `__sklearn_tags__` (or alternatively define `__sklearn_tags__` but we don't recommend this approach). Note that `BaseEstimator` needs to be on the right side of other Mixins in the inheritance order.

# %% [markdown]
# # Export joblib file

# %%
joblib.dump(logreg, "models/logistic_regression_model.joblib")
joblib.dump(rf, "models/random_forest_model.joblib")
joblib.dump(dt, "models/decision_tree_model.joblib")
joblib.dump(xgb, "models/XGBClassifier_model.joblib")
joblib.dump(knn, "models/knn_model.joblib")
joblib.dump(svc, "models/svc_model.joblib")
joblib.dump(catboost,"models/CATBoostClassifier_model.joblib")

print("New models (KNN & SVM) have been saved successfully.")
print("Models have been trained and saved successfully.")
# Out:
# New models (KNN & SVM) have been saved successfully.
# Models have been trained and saved successfully.

# %%
import json

# Collect all model metrics
model_metrics = {
    "Logistic Regression": accuracy_score(y_test, logref_pred),
    "Random Forest": accuracy_score(y_test, rf_pred),
    "Decision Tree": accuracy_score(y_test, dt_pred),
    "XGBoost": accuracy_score(y_test, xgb_pred),
    "CatBoost": accuracy_score(y_test, catboost_pred)
}

# %%
cm = confusion_matrix(y_test, catboost_pred)
tn, fp, fn, tp = cm.ravel()

fpr, tpr, _ = roc_curve(y_test, catboost_probs)
roc_auc = auc(fpr, tpr)

indices = np.linspace(0, len(fpr) - 1, 20).astype(int)
roc_data = [{"x": float(fpr[i]), "y": float(tpr[i])} for i in indices]

precision = precision_score(y_test, catboost_pred)
recall = recall_score(y_test, catboost_pred)
f1 = f1_score(y_test, catboost_pred)

feature_names = x.columns.tolist()
importances = catboost.feature_importances_
feature_importance_data = [
    {"name": name, "value": float(imp)} 
    for name, imp in zip(feature_names, importances)
]
feature_importance_data.sort(key=lambda x: x["value"], reverse=True)

metrics = {
    "Logistic Regression": accuracy_score(y_test, logref_pred),
    "Random Forest": accuracy_score(y_test, rf_pred),
    "XGBoost": acc_xgb,
    "CatBoost": acc_catboost
}

detailed_metrics = {
    "accuracy": float(acc_catboost),
    "precision": float(precision),
    "recall": float(recall),
    "f1_score": float(f1),
    "roc_auc": float(roc_auc),
    "confusion_matrix": {
        "tn": int(tn),
        "fp": int(fp),
        "fn": int(fn),
        "tp": int(tp)
    },
    "roc_curve": roc_data,
    "feature_importance": feature_importance_data,
    "model_comparison": metrics
}


with open("detailed_metrics.json", "w") as f:
    json.dump(detailed_metrics, f, indent=2)
    
# Save to JSON file
with open("model_metrics.json", "w") as f:
    json.dump(model_metrics, f, indent=2)

print("Model metrics saved to model_metrics.json")
print(json.dumps(model_metrics, indent=2))
